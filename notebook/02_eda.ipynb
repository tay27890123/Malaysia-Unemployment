# %% [markdown]
# # 02_eda.ipynb
# ## Project: Malaysia Unemployment Analysis
# ### Notebook 02: Exploratory Data Analysis (EDA)
# **Author:** TzePing + Grok
# **Date:** 12 March 2026
# **Description:** Clean analysis on processed data from 01_data_ingestion.ipynb.
# Focus: Unemployment trends, COVID impact, sector changes, and key economic insights.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# ====================== CONFIG ======================
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.3f}'.format)

plt.style.use('seaborn-v0_8-whitegrid')

# ====================== PATHS (from ingestion) ======================
ROOT = Path.cwd()
DATA_PROCESSED = ROOT / "data" / "processed"#we locate a folder using path lib 
#then we can directly call this folder and read the data set file
IMAGE_DIR = ROOT / "image_chart"

# Create image folder if missing
IMAGE_DIR.mkdir(parents=True, exist_ok=True)

# %%
# ====================== 1. LOAD CLEAN DATA ======================
df_malaysia = pd.read_csv(DATA_PROCESSED / "malaysia_clean.csv") #here is read the data set(file) use pathlib to call the folder 

print(f" Loaded clean Malaysia data: {df_malaysia.shape[0]} rows × {df_malaysia.shape[1]} columns")
print("\nColumns:\n", df_malaysia.columns.tolist())
df_malaysia.head()
# Out:
#  Loaded clean Malaysia data: 32 rows × 9 columns
#
# Columns:
#  ['Country Name', 'Year', 'Employment Sector: Agriculture', 'Employment Sector: Industry', 'Employment Sector: Services', 'Unemployment Rate', 'GDP (billion USD)', 'covid_period', 'unemp_change_pct']
#   Country Name  Year  Employment Sector: Agriculture  \
# 0     Malaysia  1991                          18.900
# 1     Malaysia  1992                          18.500
# 2     Malaysia  1993                          17.800
# 3     Malaysia  1994                          17.500
# 4     Malaysia  1995                          17.200
#
#    Employment Sector: Industry  Employment Sector: Services  \
# 0                       31.400                       49.700
# 1                       31.600                       49.900
# 2                       32.000                       50.200
# 3                       32.200                       50.300
# 4                       32.300                       50.500
#
#    Unemployment Rate  GDP (billion USD)  covid_period  unemp_change_pct
# 0              3.700             49.140             0             0.000
# 1              3.710             59.170             0             0.010
# 2              4.110             66.890             0             0.400
# 3              3.640             74.480             0            -0.470
# 4              3.150             88.710             0            -0.490
